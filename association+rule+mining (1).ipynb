# %%
# !pip install apyori
# Out:
# Collecting apyori
#   Downloading https://files.pythonhosted.org/packages/25/fd/0561e2dd29aeed544bad2d1991636e38700cdaef9530490b863741f35295/apyori-1.1.1.tar.gz
# Building wheels for collected packages: apyori
#   Running setup.py bdist_wheel for apyori: started
#   Running setup.py bdist_wheel for apyori: finished with status 'done'
#   Stored in directory: C:\Users\Shalini\AppData\Local\pip\Cache\wheels\7b\2a\35\c0c3749c1a36d4f454ea22d8396e1b854b86340d63cbbb7949
# Successfully built apyori
# Installing collected packages: apyori
# Successfully installed apyori-1.1.1
# You are using pip version 9.0.1, however version 19.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from apyori import apriori

# %%
dataset = pd.read_csv("groc.csv")

# %%
dataset.head()
# Out:
#        citrus fruit semi-finished bread       margarine  \
# 0    tropical fruit              yogurt          coffee
# 1        whole milk                 NaN             NaN
# 2         pip fruit              yogurt   cream cheese
# 3  other vegetables          whole milk  condensed milk
# 4        whole milk              butter          yogurt
#
#                 ready soups        Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 0                       NaN               NaN        NaN        NaN
# 1                       NaN               NaN        NaN        NaN
# 2              meat spreads               NaN        NaN        NaN
# 3  long life bakery product               NaN        NaN        NaN
# 4                      rice  abrasive cleaner        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 22 Unnamed: 23  \
# 0        NaN        NaN        NaN     ...             NaN         NaN
# 1        NaN        NaN        NaN     ...             NaN         NaN
# 2        NaN        NaN        NaN     ...             NaN         NaN
# 3        NaN        NaN        NaN     ...             NaN         NaN
# 4        NaN        NaN        NaN     ...             NaN         NaN
#
#   Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 30 Unnamed: 31
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 32 columns]

# %%
records = []
for i in range(1, 7501):
    records.append([str(dataset.values[i, j]) for j in range(0, 20)])

# %%
print(type(records))
# Out:
# <class 'list'>

# %%
association_rules = apriori(records, min_support=0.0045, min_confidence=0.2, min_lift=3, min_length=2)
association_results = list(association_rules)

# %%
print("There are {} Relation derived.".format(len(association_results)))
# Out:
# There are 115 Relation derived.

# %%
for i in range(0, len(association_results)):
    print(association_results[i][0])
# Out:
# frozenset({'whipped/sour cream', 'baking powder'})
# frozenset({'root vegetables', 'beef'})
# frozenset({'whipped/sour cream', 'berries'})
# frozenset({'liquor', 'bottled beer'})
# frozenset({'red/blush wine', 'bottled beer'})
# frozenset({'sugar', 'flour'})
# frozenset({'tropical fruit', 'grapes'})
# frozenset({'white bread', 'ham'})
# frozenset({'root vegetables', 'herbs'})
# frozenset({'processed cheese', 'white bread'})
# frozenset({'sliced cheese', 'sausage'})
# frozenset({'whipped/sour cream', 'baking powder', 'nan'})
# frozenset({'root vegetables', 'beef', 'nan'})
# frozenset({'root vegetables', 'beef', 'other vegetables'})
# frozenset({'root vegetables', 'beef', 'rolls/buns'})
# frozenset({'root vegetables', 'whole milk', 'beef'})
# frozenset({'root vegetables', 'beef', 'yogurt'})
# frozenset({'whipped/sour cream', 'nan', 'berries'})
# frozenset({'liquor', 'bottled beer', 'nan'})
# frozenset({'red/blush wine', 'bottled beer', 'nan'})
# frozenset({'butter', 'whole milk', 'domestic eggs'})
# frozenset({'butter', 'whipped/sour cream', 'other vegetables'})
# frozenset({'butter', 'whipped/sour cream', 'whole milk'})
# frozenset({'whipped/sour cream', 'chicken', 'other vegetables'})
# frozenset({'root vegetables', 'other vegetables', 'citrus fruit'})
# frozenset({'tropical fruit', 'pip fruit', 'citrus fruit'})
# frozenset({'tropical fruit', 'root vegetables', 'citrus fruit'})
# frozenset({'whipped/sour cream', 'yogurt', 'citrus fruit'})
# frozenset({'cream cheese ', 'root vegetables', 'other vegetables'})
# frozenset({'cream cheese ', 'yogurt', 'other vegetables'})
# frozenset({'cream cheese ', 'whole milk', 'yogurt'})
# frozenset({'root vegetables', 'curd', 'other vegetables'})
# frozenset({'root vegetables', 'curd', 'yogurt'})
# frozenset({'tropical fruit', 'curd', 'yogurt'})
# frozenset({'whipped/sour cream', 'whole milk', 'curd'})
# frozenset({'dessert', 'yogurt', 'other vegetables'})
# frozenset({'whole milk', 'domestic eggs', 'margarine'})
# frozenset({'whipped/sour cream', 'domestic eggs', 'other vegetables'})
# frozenset({'sugar', 'flour', 'nan'})
# frozenset({'root vegetables', 'frozen vegetables', 'other vegetables'})
# frozenset({'tropical fruit', 'fruit/vegetable juice', 'other vegetables'})
# frozenset({'tropical fruit', 'grapes', 'nan'})
# frozenset({'white bread', 'ham', 'nan'})
# frozenset({'whole milk', 'hard cheese', 'yogurt'})
# frozenset({'root vegetables', 'herbs', 'nan'})
# frozenset({'white bread', 'processed cheese', 'nan'})
# frozenset({'sliced cheese', 'sausage', 'nan'})
# frozenset({'root vegetables', 'other vegetables', 'onions'})
# frozenset({'tropical fruit', 'pip fruit', 'other vegetables'})
# frozenset({'whipped/sour cream', 'pip fruit', 'other vegetables'})
# frozenset({'root vegetables', 'pork', 'other vegetables'})
# frozenset({'tropical fruit', 'root vegetables', 'other vegetables'})
# frozenset({'whipped/sour cream', 'sausage', 'other vegetables'})
# frozenset({'tropical fruit', 'whipped/sour cream', 'other vegetables'})
# frozenset({'whipped/sour cream', 'yogurt', 'other vegetables'})
# frozenset({'tropical fruit', 'root vegetables', 'pip fruit'})
# frozenset({'tropical fruit', 'yogurt', 'pip fruit'})
# frozenset({'shopping bags', 'sausage', 'rolls/buns'})
# frozenset({'tropical fruit', 'whipped/sour cream', 'root vegetables'})
# frozenset({'tropical fruit', 'root vegetables', 'yogurt'})
# frozenset({'whipped/sour cream', 'root vegetables', 'yogurt'})
# frozenset({'tropical fruit', 'whipped/sour cream', 'yogurt'})
# frozenset({'root vegetables', 'beef', 'other vegetables', 'nan'})
# frozenset({'root vegetables', 'whole milk', 'beef', 'nan'})
# frozenset({'butter', 'whole milk', 'domestic eggs', 'nan'})
# frozenset({'butter', 'whipped/sour cream', 'other vegetables', 'nan'})
# frozenset({'butter', 'whipped/sour cream', 'whole milk', 'nan'})
# frozenset({'nan', 'whole milk', 'domestic eggs', 'citrus fruit'})
# frozenset({'root vegetables', 'nan', 'other vegetables', 'citrus fruit'})
# frozenset({'tropical fruit', 'nan', 'pip fruit', 'citrus fruit'})
# frozenset({'whipped/sour cream', 'yogurt', 'nan', 'citrus fruit'})
# frozenset({'tropical fruit', 'root vegetables', 'other vegetables', 'citrus fruit'})
# frozenset({'root vegetables', 'whole milk', 'other vegetables', 'citrus fruit'})
# frozenset({'tropical fruit', 'whole milk', 'other vegetables', 'citrus fruit'})
# frozenset({'cream cheese ', 'yogurt', 'other vegetables', 'nan'})
# frozenset({'cream cheese ', 'whole milk', 'yogurt', 'nan'})
# frozenset({'tropical fruit', 'yogurt', 'curd', 'nan'})
# frozenset({'whipped/sour cream', 'whole milk', 'curd', 'nan'})
# frozenset({'whole milk', 'domestic eggs', 'margarine', 'nan'})
# frozenset({'root vegetables', 'whole milk', 'domestic eggs', 'other vegetables'})
# frozenset({'root vegetables', 'frozen vegetables', 'other vegetables', 'nan'})
# frozenset({'fruit/vegetable juice', 'yogurt', 'whole milk', 'other vegetables'})
# frozenset({'root vegetables', 'onions', 'other vegetables', 'nan'})
# frozenset({'tropical fruit', 'other vegetables', 'pip fruit', 'nan'})
# frozenset({'whipped/sour cream', 'other vegetables', 'pip fruit', 'nan'})
# frozenset({'root vegetables', 'other vegetables', 'pork', 'nan'})
# frozenset({'tropical fruit', 'root vegetables', 'other vegetables', 'nan'})
# frozenset({'tropical fruit', 'yogurt', 'pip fruit', 'nan'})
# frozenset({'shopping bags', 'sausage', 'rolls/buns', 'nan'})
# frozenset({'whipped/sour cream', 'root vegetables', 'yogurt', 'nan'})
# frozenset({'root vegetables', 'whole milk', 'pip fruit', 'other vegetables'})
# frozenset({'tropical fruit', 'whole milk', 'pip fruit', 'other vegetables'})
# frozenset({'whole milk', 'yogurt', 'pip fruit', 'other vegetables'})
# frozenset({'root vegetables', 'whole milk', 'rolls/buns', 'other vegetables'})
# frozenset({'root vegetables', 'whole milk', 'soda', 'other vegetables'})
# frozenset({'tropical fruit', 'root vegetables', 'whole milk', 'other vegetables'})
# frozenset({'tropical fruit', 'root vegetables', 'yogurt', 'other vegetables'})
# frozenset({'whipped/sour cream', 'root vegetables', 'whole milk', 'other vegetables'})
# frozenset({'root vegetables', 'whole milk', 'yogurt', 'other vegetables'})
# frozenset({'tropical fruit', 'whipped/sour cream', 'whole milk', 'other vegetables'})
# frozenset({'tropical fruit', 'whole milk', 'yogurt', 'other vegetables'})
# frozenset({'whipped/sour cream', 'whole milk', 'yogurt', 'other vegetables'})
# frozenset({'tropical fruit', 'whole milk', 'yogurt', 'rolls/buns'})
# frozenset({'tropical fruit', 'root vegetables', 'whole milk', 'yogurt'})
# frozenset({'tropical fruit', 'whipped/sour cream', 'whole milk', 'yogurt'})
# frozenset({'citrus fruit', 'whole milk', 'other vegetables', 'root vegetables', 'nan'})
# frozenset({'tropical fruit', 'citrus fruit', 'whole milk', 'other vegetables', 'nan'})
# frozenset({'yogurt', 'whole milk', 'other vegetables', 'fruit/vegetable juice', 'nan'})
# frozenset({'pip fruit', 'whole milk', 'other vegetables', 'root vegetables', 'nan'})
# frozenset({'tropical fruit', 'whole milk', 'other vegetables', 'root vegetables', 'nan'})
# frozenset({'tropical fruit', 'yogurt', 'other vegetables', 'root vegetables', 'nan'})
# frozenset({'yogurt', 'whole milk', 'other vegetables', 'root vegetables', 'nan'})
# frozenset({'tropical fruit', 'yogurt', 'whole milk', 'other vegetables', 'nan'})
# frozenset({'tropical fruit', 'yogurt', 'whole milk', 'rolls/buns', 'nan'})
# frozenset({'tropical fruit', 'yogurt', 'whole milk', 'root vegetables', 'nan'})

# %%
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0]
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    # second index of the inner list
    print("Support: " + str(item[1]))

    # third index of the list located at 0th
    # of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: whipped/sour cream -> baking powder
# Support: 0.005066666666666666
# Confidence: 0.2835820895522388
# Lift: 3.8811417365726113
# =====================================
# Rule: root vegetables -> beef
# Support: 0.0176
# Confidence: 0.3464566929133859
# Lift: 3.1344091638726104
# =====================================
# Rule: whipped/sour cream -> berries
# Support: 0.007733333333333333
# Confidence: 0.25
# Lift: 3.4215328467153285
# =====================================
# Rule: liquor -> bottled beer
# Support: 0.004533333333333334
# Confidence: 0.40963855421686746
# Lift: 5.069784086842419
# =====================================
# Rule: red/blush wine -> bottled beer
# Support: 0.004933333333333333
# Confidence: 0.2624113475177305
# Lift: 3.24766519205112
# =====================================
# Rule: sugar -> flour
# Support: 0.005066666666666666
# Confidence: 0.28787878787878785
# Lift: 8.636363636363635
# =====================================
# Rule: tropical fruit -> grapes
# Support: 0.006
# Confidence: 0.32608695652173914
# Lift: 3.1075631180597756
# =====================================
# Rule: white bread -> ham
# Support: 0.005333333333333333
# Confidence: 0.20833333333333331
# Lift: 4.82253086419753
# =====================================
# Rule: root vegetables -> herbs
# Support: 0.006533333333333334
# Confidence: 0.40495867768595045
# Lift: 3.6636792311756676
# =====================================
# Rule: processed cheese -> white bread
# Support: 0.0048
# Confidence: 0.30252100840336127
# Lift: 7.0028011204481775
# =====================================
# Rule: sliced cheese -> sausage
# Support: 0.006933333333333333
# Confidence: 0.30057803468208094
# Lift: 3.238987442694838
# =====================================
# Rule: whipped/sour cream -> baking powder
# Support: 0.005066666666666666
# Confidence: 0.2857142857142857
# Lift: 3.9103232533889467
# =====================================
# Rule: root vegetables -> beef
# Support: 0.0168
# Confidence: 0.33962264150943394
# Lift: 3.0725811958030818
# =====================================
# Rule: root vegetables -> beef
# Support: 0.007333333333333333
# Confidence: 0.4044117647058823
# Lift: 3.6587312850351235
# =====================================
# Rule: root vegetables -> beef
# Support: 0.0048
# Confidence: 0.3636363636363636
# Lift: 3.289834411667946
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.008533333333333334
# Confidence: 0.42384105960264906
# Lift: 3.8345089831361494
# =====================================
# Rule: root vegetables -> beef
# Support: 0.0048
# Confidence: 0.44444444444444436
# Lift: 4.020908725371934
# =====================================
# Rule: whipped/sour cream -> nan
# Support: 0.007733333333333333
# Confidence: 0.2521739130434783
# Lift: 3.451285306251984
# =====================================
# Rule: liquor -> bottled beer
# Support: 0.004533333333333334
# Confidence: 0.40963855421686746
# Lift: 5.069784086842419
# =====================================
# Rule: red/blush wine -> bottled beer
# Support: 0.004933333333333333
# Confidence: 0.2624113475177305
# Lift: 3.24766519205112
# =====================================
# Rule: butter -> whole milk
# Support: 0.0061333333333333335
# Confidence: 0.22222222222222224
# Lift: 3.4435261707988984
# =====================================
# Rule: butter -> whipped/sour cream
# Support: 0.0061333333333333335
# Confidence: 0.3172413793103448
# Lift: 4.341807198590486
# =====================================
# Rule: butter -> whipped/sour cream
# Support: 0.006933333333333333
# Confidence: 0.25120772946859904
# Lift: 3.438061990902359
# =====================================
# Rule: whipped/sour cream -> chicken
# Support: 0.004533333333333334
# Confidence: 0.265625
# Lift: 3.635378649635036
# =====================================
# Rule: root vegetables -> other vegetables
# Support: 0.010666666666666666
# Confidence: 0.37209302325581395
# Lift: 3.36634218868348
# =====================================
# Rule: tropical fruit -> pip fruit
# Support: 0.005733333333333333
# Confidence: 0.4056603773584906
# Lift: 3.8658866965548655
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.005733333333333333
# Confidence: 0.32824427480916035
# Lift: 3.128122059807754
# =====================================
# Rule: whipped/sour cream -> yogurt
# Support: 0.005066666666666666
# Confidence: 0.46341463414634143
# Lift: 3.377657683282372
# =====================================
# Rule: cream cheese  -> root vegetables
# Support: 0.004666666666666667
# Confidence: 0.5932203389830509
# Lift: 3.0854039822280734
# =====================================
# Rule: cream cheese  -> yogurt
# Support: 0.006266666666666667
# Confidence: 0.4392523364485981
# Lift: 3.201547641753631
# =====================================
# Rule: cream cheese  -> whole milk
# Support: 0.0072
# Confidence: 0.4462809917355372
# Lift: 3.2527769076934203
# =====================================
# Rule: root vegetables -> curd
# Support: 0.0061333333333333335
# Confidence: 0.3407407407407408
# Lift: 3.0826966894518164
# =====================================
# Rule: root vegetables -> curd
# Support: 0.004666666666666667
# Confidence: 0.42168674698795183
# Lift: 3.073518564052127
# =====================================
# Rule: tropical fruit -> curd
# Support: 0.0052
# Confidence: 0.52
# Lift: 3.7900874635568518
# =====================================
# Rule: whipped/sour cream -> whole milk
# Support: 0.0061333333333333335
# Confidence: 0.2433862433862434
# Lift: 3.3310161047387328
# =====================================
# Rule: dessert -> yogurt
# Support: 0.004666666666666667
# Confidence: 0.4117647058823529
# Lift: 3.001200480192077
# =====================================
# Rule: whole milk -> domestic eggs
# Support: 0.005333333333333333
# Confidence: 0.2094240837696335
# Lift: 3.245207909653412
# =====================================
# Rule: whipped/sour cream -> domestic eggs
# Support: 0.005066666666666666
# Confidence: 0.22891566265060237
# Lift: 3.1329698355465654
# =====================================
# Rule: sugar -> flour
# Support: 0.004933333333333333
# Confidence: 0.29365079365079366
# Lift: 8.80952380952381
# =====================================
# Rule: root vegetables -> frozen vegetables
# Support: 0.006266666666666667
# Confidence: 0.3560606060606061
# Lift: 3.2212961947581973
# =====================================
# Rule: tropical fruit -> fruit/vegetable juice
# Support: 0.006533333333333334
# Confidence: 0.31612903225806455
# Lift: 3.0126654916588107
# =====================================
# Rule: tropical fruit -> grapes
# Support: 0.005733333333333333
# Confidence: 0.3161764705882353
# Lift: 3.0131175723148216
# =====================================
# Rule: white bread -> ham
# Support: 0.005066666666666666
# Confidence: 0.20212765957446807
# Lift: 4.678881008668242
# =====================================
# Rule: whole milk -> hard cheese
# Support: 0.004666666666666667
# Confidence: 0.4666666666666667
# Lift: 3.4013605442176873
# =====================================
# Rule: root vegetables -> herbs
# Support: 0.0064
# Confidence: 0.4
# Lift: 3.618817852834741
# =====================================
# Rule: white bread -> processed cheese
# Support: 0.004666666666666667
# Confidence: 0.2991452991452992
# Lift: 6.924659702437481
# =====================================
# Rule: sliced cheese -> sausage
# Support: 0.0068
# Confidence: 0.3072289156626506
# Lift: 3.3106564187785628
# =====================================
# Rule: root vegetables -> other vegetables
# Support: 0.005733333333333333
# Confidence: 0.4174757281553398
# Lift: 3.7769215454343166
# =====================================
# Rule: tropical fruit -> pip fruit
# Support: 0.009333333333333334
# Confidence: 0.37234042553191493
# Lift: 3.5483522128200278
# =====================================
# Rule: whipped/sour cream -> pip fruit
# Support: 0.0054666666666666665
# Confidence: 0.5774647887323944
# Lift: 3.0034576390381122
# =====================================
# Rule: root vegetables -> pork
# Support: 0.007066666666666666
# Confidence: 0.3419354838709677
# Lift: 3.093505583874859
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.013066666666666667
# Confidence: 0.368421052631579
# Lift: 3.3331217065583143
# =====================================
# Rule: whipped/sour cream -> sausage
# Support: 0.0052
# Confidence: 0.582089552238806
# Lift: 3.027511540770489
# =====================================
# Rule: tropical fruit -> whipped/sour cream
# Support: 0.008266666666666667
# Confidence: 0.2330827067669173
# Lift: 3.1900005488172987
# =====================================
# Rule: whipped/sour cream -> yogurt
# Support: 0.010266666666666667
# Confidence: 0.23475609756097562
# Lift: 3.2129027950863454
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.005333333333333333
# Confidence: 0.3333333333333333
# Lift: 3.1766200762388817
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.0064
# Confidence: 0.35036496350364965
# Lift: 3.3389291312291896
# =====================================
# Rule: shopping bags -> sausage
# Support: 0.005866666666666667
# Confidence: 0.2913907284768212
# Lift: 3.139986298241608
# =====================================
# Rule: tropical fruit -> whipped/sour cream
# Support: 0.005066666666666666
# Confidence: 0.22891566265060237
# Lift: 3.1329698355465654
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.0088
# Confidence: 0.32038834951456313
# Lift: 3.053256189783003
# =====================================
# Rule: whipped/sour cream -> root vegetables
# Support: 0.0068
# Confidence: 0.24757281553398056
# Lift: 3.3883140812132373
# =====================================
# Rule: tropical fruit -> whipped/sour cream
# Support: 0.0068
# Confidence: 0.45945945945945943
# Lift: 3.3488298794421243
# =====================================
# Rule: root vegetables -> beef
# Support: 0.006666666666666667
# Confidence: 0.3875968992248062
# Lift: 3.5066064465452915
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.007866666666666666
# Confidence: 0.41258741258741255
# Lift: 3.732696736315554
# =====================================
# Rule: butter -> whole milk
# Support: 0.005333333333333333
# Confidence: 0.20100502512562815
# Lift: 3.114747290169858
# =====================================
# Rule: butter -> whipped/sour cream
# Support: 0.005066666666666666
# Confidence: 0.2794117647058823
# Lift: 3.824066122799484
# =====================================
# Rule: butter -> whipped/sour cream
# Support: 0.006
# Confidence: 0.22613065326633167
# Lift: 3.0948538311997944
# =====================================
# Rule: nan -> whole milk
# Support: 0.006
# Confidence: 0.2
# Lift: 3.0991735537190084
# =====================================
# Rule: root vegetables -> nan
# Support: 0.009866666666666666
# Confidence: 0.357487922705314
# Lift: 3.23420919214699
# =====================================
# Rule: tropical fruit -> nan
# Support: 0.0052
# Confidence: 0.3823529411764706
# Lift: 3.6437700874504824
# =====================================
# Rule: whipped/sour cream -> yogurt
# Support: 0.0048
# Confidence: 0.4556962025316455
# Lift: 3.3214008930877954
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.004666666666666667
# Confidence: 0.43750000000000006
# Lift: 4.169313850063533
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.0061333333333333335
# Confidence: 0.46464646464646464
# Lift: 4.203677303797931
# =====================================
# Rule: tropical fruit -> whole milk
# Support: 0.0052
# Confidence: 0.3939393939393939
# Lift: 3.754187362827769
# =====================================
# Rule: cream cheese  -> yogurt
# Support: 0.005733333333333333
# Confidence: 0.42574257425742573
# Lift: 3.103079987299022
# =====================================
# Rule: cream cheese  -> whole milk
# Support: 0.0064
# Confidence: 0.4210526315789474
# Lift: 3.068896731624981
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.004533333333333334
# Confidence: 0.4927536231884058
# Lift: 3.591498711285757
# =====================================
# Rule: whipped/sour cream -> whole milk
# Support: 0.0056
# Confidence: 0.22950819672131145
# Lift: 3.1410793346894814
# =====================================
# Rule: whole milk -> domestic eggs
# Support: 0.0052
# Confidence: 0.20855614973262032
# Lift: 3.2317585185839928
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.004666666666666667
# Confidence: 0.3608247422680413
# Lift: 3.2643975476602045
# =====================================
# Rule: root vegetables -> frozen vegetables
# Support: 0.0054666666666666665
# Confidence: 0.3333333333333333
# Lift: 3.0156815440289506
# =====================================
# Rule: fruit/vegetable juice -> yogurt
# Support: 0.0054666666666666665
# Confidence: 0.5466666666666666
# Lift: 3.9844509232264333
# =====================================
# Rule: root vegetables -> onions
# Support: 0.005333333333333333
# Confidence: 0.40404040404040403
# Lift: 3.65537156851994
# =====================================
# Rule: tropical fruit -> other vegetables
# Support: 0.0084
# Confidence: 0.35
# Lift: 3.3354510800508255
# =====================================
# Rule: whipped/sour cream -> other vegetables
# Support: 0.004933333333333333
# Confidence: 0.5781249999999999
# Lift: 3.0068914701803044
# =====================================
# Rule: root vegetables -> other vegetables
# Support: 0.006933333333333333
# Confidence: 0.3398692810457516
# Lift: 3.0748125546961846
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.0116
# Confidence: 0.34661354581673304
# Lift: 3.1358282190898645
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.0056
# Confidence: 0.32558139534883723
# Lift: 3.1027451907449546
# =====================================
# Rule: shopping bags -> sausage
# Support: 0.005866666666666667
# Confidence: 0.2913907284768212
# Lift: 3.139986298241608
# =====================================
# Rule: whipped/sour cream -> root vegetables
# Support: 0.005733333333333333
# Confidence: 0.22051282051282053
# Lift: 3.0179674340258282
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.005333333333333333
# Confidence: 0.42105263157894735
# Lift: 3.8092819503523585
# =====================================
# Rule: tropical fruit -> whole milk
# Support: 0.0048
# Confidence: 0.3789473684210526
# Lift: 3.611315455092623
# =====================================
# Rule: whole milk -> yogurt
# Support: 0.0054666666666666665
# Confidence: 0.43157894736842106
# Lift: 3.1456191499156057
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.0061333333333333335
# Confidence: 0.33333333333333337
# Lift: 3.015681544028951
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.004933333333333333
# Confidence: 0.34579439252336447
# Lift: 3.1284173026842383
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.007466666666666667
# Confidence: 0.4444444444444445
# Lift: 4.0209087253719344
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.0054666666666666665
# Confidence: 0.4183673469387755
# Lift: 3.0493246861426786
# =====================================
# Rule: whipped/sour cream -> root vegetables
# Support: 0.0054666666666666665
# Confidence: 0.22527472527472528
# Lift: 3.0831394882489773
# =====================================
# Rule: root vegetables -> whole milk
# Support: 0.008533333333333334
# Confidence: 0.37209302325581395
# Lift: 3.36634218868348
# =====================================
# Rule: tropical fruit -> whipped/sour cream
# Support: 0.004666666666666667
# Confidence: 0.27777777777777785
# Lift: 3.8017031630170326
# =====================================
# Rule: tropical fruit -> whole milk
# Support: 0.008
# Confidence: 0.4761904761904762
# Lift: 3.4707760655282525
# =====================================
# Rule: whipped/sour cream -> whole milk
# Support: 0.005733333333333333
# Confidence: 0.25
# Lift: 3.4215328467153285
# =====================================
# Rule: tropical fruit -> whole milk
# Support: 0.005066666666666666
# Confidence: 0.4691358024691358
# Lift: 3.4193571608537594
# =====================================
# Rule: tropical fruit -> root vegetables
# Support: 0.0064
# Confidence: 0.5052631578947369
# Lift: 3.6826760779499774
# =====================================
# Rule: tropical fruit -> whipped/sour cream
# Support: 0.005066666666666666
# Confidence: 0.5846153846153846
# Lift: 4.261045077371609
# =====================================
# Rule: citrus fruit -> whole milk
# Support: 0.0054666666666666665
# Confidence: 0.4361702127659574
# Lift: 3.946051382080435
# =====================================
# Rule: tropical fruit -> citrus fruit
# Support: 0.004666666666666667
# Confidence: 0.37234042553191493
# Lift: 3.5483522128200278
# =====================================
# Rule: yogurt -> whole milk
# Support: 0.005066666666666666
# Confidence: 0.5277777777777778
# Lift: 3.84677680596048
# =====================================
# Rule: pip fruit -> whole milk
# Support: 0.004666666666666667
# Confidence: 0.3888888888888889
# Lift: 3.5182951347004425
# =====================================
# Rule: tropical fruit -> whole milk
# Support: 0.006266666666666667
# Confidence: 0.4017094017094017
# Lift: 3.634282886393864
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.004533333333333334
# Confidence: 0.3617021276595745
# Lift: 3.4469707210251697
# =====================================
# Rule: yogurt -> whole milk
# Support: 0.007333333333333333
# Confidence: 0.3395061728395061
# Lift: 3.0715274985480048
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.0072
# Confidence: 0.46153846153846156
# Lift: 3.363982955819691
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.0048
# Confidence: 0.46753246753246747
# Lift: 3.407671046155011
# =====================================
# Rule: tropical fruit -> yogurt
# Support: 0.0054666666666666665
# Confidence: 0.48235294117647054
# Lift: 3.515691991082147
# =====================================
