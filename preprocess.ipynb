# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#import dataset
data=pd.read_csv('College.csv')

# %%
#to view top n element(5 by default)
data.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660     NaN   721.0         23
# 1            Adelphi University     Yes  2186  1924.0   512.0         16
# 2                Adrian College     Yes  1428  1097.0     NaN         22
# 3           Agnes Scott College     Yes   417   349.0   137.0         60
# 4     Alaska Pacific University     Yes   193   146.0    55.0         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0       52.0       2885.0        537.0    7440.0      3300.0  450.0    2200.0
# 1       29.0       2683.0       1227.0   12280.0      6450.0  750.0    1500.0
# 2        NaN       1036.0         99.0   11250.0      3750.0  400.0    1165.0
# 3       89.0        510.0         63.0       NaN      5450.0  450.0     875.0
# 4        NaN        249.0        869.0    7560.0      4120.0  800.0    1500.0
#
# ...

# %%
data.head(10)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660     NaN   721.0         23
# 1            Adelphi University     Yes  2186  1924.0   512.0         16
# 2                Adrian College     Yes  1428  1097.0     NaN         22
# 3           Agnes Scott College     Yes   417   349.0   137.0         60
# 4     Alaska Pacific University     Yes   193   146.0    55.0         16
# 5             Albertson College     Yes   587     NaN   158.0         38
# 6       Albertus Magnus College     Yes   353   340.0   103.0         17
# 7                Albion College     Yes  1899  1720.0   489.0         37
# 8              Albright College     NaN  1038   839.0   227.0         30
# 9     Alderson-Broaddus College     Yes   582   498.0   172.0         21
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0       52.0       2885.0        537.0    7440.0      3300.0  450.0    2200.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
# Unnamed: 0     777 non-null object
# Private        775 non-null object
# Apps           777 non-null int64
# Accept         750 non-null float64
# Enroll         776 non-null float64
# Top10perc      777 non-null int64
# Top25perc      775 non-null float64
# F.Undergrad    776 non-null float64
# P.Undergrad    776 non-null float64
# Outstate       775 non-null float64
# Room.Board     775 non-null float64
# Books          776 non-null float64
# Personal       776 non-null float64
# PhD            774 non-null float64
# Terminal       777 non-null int64
# S.F.Ratio      769 non-null float64
# perc.alumni    777 non-null int64
# Expend         757 non-null float64
# Grad.Rate      776 non-null float64
# dtypes: float64(13), int64(4), object(2)
# memory usage: 115.4+ KB

# %%
#to view some basic statistical details
data.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    750.000000   776.000000  777.000000  775.000000
# mean    3001.638353   2000.606667   780.545103   27.558559   55.819355
# std     3870.201484   2427.409450   929.638505   17.640364   19.824707
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    597.250000   242.000000   15.000000   41.000000
# 50%     1558.000000   1104.500000   435.500000   23.000000   54.000000
# 75%     3624.000000   2399.500000   902.250000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    776.000000    776.000000    775.000000   775.000000   776.000000
# mean    3697.140464    854.426546  10435.909677  4355.055484   549.509021
# std     4852.935209   1523.219593   4026.970686  1096.667666   165.173223
# ...

# %%
data['Enroll'].describe()
# Out:
# count     776.000000
# mean      780.545103
# std       929.638505
# min        35.000000
# 25%       242.000000
# 50%       435.500000
# 75%       902.250000
# max      6392.000000
# Name: Enroll, dtype: float64

# %%
#sum of values
data['Outstate'].sum()
# Out:
# 8087830.0

# %%
data.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660     NaN   721.0         23
# 1            Adelphi University     Yes  2186  1924.0   512.0         16
# 2                Adrian College     Yes  1428  1097.0     NaN         22
# 3           Agnes Scott College     Yes   417   349.0   137.0         60
# 4     Alaska Pacific University     Yes   193   146.0    55.0         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0       52.0       2885.0        537.0    7440.0      3300.0  450.0    2200.0
# 1       29.0       2683.0       1227.0   12280.0      6450.0  750.0    1500.0
# 2        NaN       1036.0         99.0   11250.0      3750.0  400.0    1165.0
# 3       89.0        510.0         63.0       NaN      5450.0  450.0     875.0
# 4        NaN        249.0        869.0    7560.0      4120.0  800.0    1500.0
#
# ...

# %%
#Back-fill or forward-fill to propagate next or previous values respectively
#for back fill
data.fillna(method='bfill',inplace=True)

# %%
#for forward-fill
data.fillna(method='ffill',inplace=True)

# %%
# sum of null values
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Private        0
# Apps           0
# Accept         0
# Enroll         0
# Top10perc      0
# Top25perc      0
# F.Undergrad    0
# P.Undergrad    0
# Outstate       0
# Room.Board     0
# Books          0
# Personal       0
# PhD            0
# Terminal       0
# S.F.Ratio      0
# perc.alumni    0
# Expend         0
# Grad.Rate      0
# dtype: int64

# %%
#handle null value by fill median
median=data.median()

# %%
data.fillna(median,inplace=True)

# %%
data['Accept'].head(10)
# Out:
# 0    1924.0
# 1    1924.0
# 2    1097.0
# 3     349.0
# 4     146.0
# 5     340.0
# 6     340.0
# 7    1720.0
# 8     839.0
# 9     498.0
# Name: Accept, dtype: float64

# %%
#handled all null value
data['Accept'].isnull().sum()
# Out:
# 0

# %%
data.head(10)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660  1924.0   721.0         23
# 1            Adelphi University     Yes  2186  1924.0   512.0         16
# 2                Adrian College     Yes  1428  1097.0   137.0         22
# 3           Agnes Scott College     Yes   417   349.0   137.0         60
# 4     Alaska Pacific University     Yes   193   146.0    55.0         16
# 5             Albertson College     Yes   587   340.0   158.0         38
# 6       Albertus Magnus College     Yes   353   340.0   103.0         17
# 7                Albion College     Yes  1899  1720.0   489.0         37
# 8              Albright College     Yes  1038   839.0   227.0         30
# 9     Alderson-Broaddus College     Yes   582   498.0   172.0         21
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0       52.0       2885.0        537.0    7440.0      3300.0  450.0    2200.0
# ...

# %%
#Encoding categorial value-Find and replace
data["Private"].value_counts()
# Out:
# Yes    565
# No     212
# Name: Private, dtype: int64

# %%
#replace with
rep = {"Private": {"Yes": 1, "No": 0}}

# %%
data.replace(rep,inplace=True)
data.head()
# Out:
#                      Unnamed: 0  Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University        1  1660  1924.0   721.0         23
# 1            Adelphi University        1  2186  1924.0   512.0         16
# 2                Adrian College        1  1428  1097.0   137.0         22
# 3           Agnes Scott College        1   417   349.0   137.0         60
# 4     Alaska Pacific University        1   193   146.0    55.0         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0       52.0       2885.0        537.0    7440.0      3300.0  450.0    2200.0
# 1       29.0       2683.0       1227.0   12280.0      6450.0  750.0    1500.0
# 2       89.0       1036.0         99.0   11250.0      3750.0  400.0    1165.0
# 3       89.0        510.0         63.0    7560.0      5450.0  450.0     875.0
# 4       62.0        249.0        869.0    7560.0      4120.0  800.0    1500.0
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lb_pri = LabelEncoder()
data["Pri_new"] = lb_pri.fit_transform(data["PhD"])
data[["PhD", "Pri_new"]].head(11)
# Out:
#      PhD  Pri_new
# 0   70.0       46
# 1   29.0        7
# 2   53.0       29
# 3   92.0       68
# 4   76.0       52
# 5   67.0       43
# 6   90.0       66
# 7   89.0       65
# 8   79.0       55
# 9   40.0       16
# 10  82.0       58

# %%
#split data into label and feature
Y=data.Apps
X=data.drop('Apps',axis=1)

# %%
#split the data in to training and testing
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)
X_train.head()
# Out:
#                      Unnamed: 0  Private  Accept  Enroll  Top10perc  \
# 87   Carnegie Mellon University        1  5201.0  1191.0         60
# 692       University of Vermont        0  6008.0  1735.0         18
# 590     Transylvania University        1   729.0   244.0         57
# 594          Trinity College DC        1   189.0   100.0         19
# 231  Grace College and Seminary        1   428.0   167.0         18
#
#      Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# 87        89.0       4265.0        291.0   17900.0      5690.0  450.0
# 692       51.0       7353.0       1674.0   15516.0      4928.0  500.0
# 590       81.0        867.0         51.0   10900.0      4450.0  500.0
# 594       49.0        309.0        639.0   11412.0      6430.0  500.0
# 231       46.0        618.0        113.0    8958.0      3670.0  300.0
#
#      Personal   PhD  Terminal  S.F.Ratio  perc.alumni   Expend  Grad.Rate  \
# ...

# %%
array = data.values
X = array[:,1:9]
Y = array[:,0]

# %%
X
# Out:
# array([[1, 1660, 1924.0, ..., 52.0, 2885.0, 537.0],
#        [1, 2186, 1924.0, ..., 29.0, 2683.0, 1227.0],
#        [1, 1428, 1097.0, ..., 89.0, 1036.0, 99.0],
#        ...,
#        [1, 2097, 1915.0, ..., 61.0, 2793.0, 166.0],
#        [1, 10705, 2453.0, ..., 99.0, 5217.0, 83.0],
#        [1, 2989, 2453.0, ..., 63.0, 2988.0, 1726.0]], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
rescaledX
# Out:
# array([[ 0.61255305, -0.34688182, -0.03339659, ..., -0.195225  ,
#         -0.16671555, -0.20794171],
#        [ 0.61255305, -0.21088404, -0.03339659, ..., -1.35547306,
#         -0.20838295,  0.24554859],
#        [ 0.61255305, -0.40686563, -0.37223965, ...,  1.67126102,
#         -0.5481167 , -0.49580947],
#        ...,
#        [ 0.61255305, -0.23389507, -0.03708412, ...,  0.25878512,
#         -0.18569278, -0.4517749 ],
#        [ 0.61255305,  1.99171118,  0.18334825, ...,  2.1757167 ,
#          0.31431608, -0.50632519],
#        [ 0.61255305, -0.00326766,  0.18334825, ...,  0.35967625,
#         -0.1454693 ,  0.57350753]])
